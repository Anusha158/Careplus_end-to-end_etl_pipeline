# %%
import pyarrow.parquet as pq
import pandas as pd

# %%
table=pq.read_table("run-1771632618238-part-block-0-r-00000-snappy.parquet")
print(table.schema)
# Out:
# ticket_id: string
# created_at: timestamp[ns]
# resolved_at: timestamp[ns]
# issue_category: string
# agent: string
# num_interactions: int32
# priority: string
# channel: string
# status: string
# is_change: double
# manager: string
